# %% [markdown]
# #Data Types and Structures Questions

# %% [markdown]
# 1.  What are data structures, and why are they important?
#     - Data structure is a way of arrangement of data or we can say it as a way of storing and organising data within a program. They provide a systematic way to manage data efficiently, enabling faster access, modification, and storage. Common examples include arrays, lists, tuples, stacks, queues and sets.
#     - Why Data Structures Are Important:
#      Data structures are fundamental in Python because they determine how data is stored, accessed, and manipulated, directly affecting the performance, scalability, and maintainability of your programs.
#      Here’s why they are important:
#       - Efficient Data Management
#       - Optimized Performance
#       - Problem-Solving Power
#       - Code Readability & Maintainability
#       - Real-World Applications

# %% [markdown]
# 2. Explain the difference between mutable and immutable data types with examples
#    - Mutable data types are the data types which can be changed after creation.this means they can add, remove or modify existing elements of that data types. these include the following:
#       - Lists: these can store heterogeneous data.these are defines using square brackets: list1=[1,2,3,4]
#       - Dictionaries: these store values in curly braces{}. these store values in the form of key:value pairs. eg: dict1={1:"value1",2:"value2"}
#       - Sets: these store values in curly braces{}. eg: set1={1,2,3}

# %%
# Example of list as a mutable data type/structure
list1=[1,2,3,4]
list1.append(5)
print(list1)
# adding elements is possible
list1.remove(4)
print(list1)
# removing elements is possible
list1[0]=6
print(list1)
# Updating values is also possible
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 5]
# [6, 2, 3, 5]

# %% [markdown]
# - Immutable data types are the data types which cannoot be changed after creation. when we try to add, remove or modify any value in these data types, it throws error. these include:
#   - Tuples: tuples are immuatable data typles which store heterogeneous data. these are defined using parenthesis ().eg- tuple1=(1,2,3,4)
#   - Strings: strings are sequence of characters stored in single or double quotes. eg- 'str1',"str2".

# %%
# Example of list as a mutable data type/structure
tuple1=(1,2,3,4)
print(tuple1)
tuple1[1]=10
# this will throw an error, because we cannot change or add values
# to an immutable object.
# Out:
# (1, 2, 3, 4)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4293028090.py in <cell line: 0>()
#       2 tuple1=(1,2,3,4)
#       3 print(tuple1)
# ----> 4 tuple1[1]=10
#       5 # this will throw an error, because we cannot change or add values
#       6 # to an immutable object.
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 3. What are the main differences between lists and tuples in Python?
#    - The main difference between lists and tuples in python is that lists are mutable i.e., elements in the lists can be added, modified, or removed. and tuples are immutable, i.e., elements in a tuple cannot be added, modiied or removed once created. the examples are discussed above.

# %% [markdown]
# 4. Describe how dictionaries store data?
#    - Dictionaries in Python are a built-in data structure that store data in key-value pairs.Dictionaries maintain the insertion order of keys. Keys in a dictionary must be immutable (e.g., strings, numbers, or tuples) and unique, while values can be of any data type and can be duplicated. they can be defined as: dict1={Key:"value"}, and there can n number of key: value pairs.

# %%
# Example of a dictionary
dict1={1:"Agra", 2:"Amritsar", 3:"Delhi"}
print(dict1)
# adding vales to a dictionary
dict1[4]="Mumbai"
print(dict1)
# modifyinng values in a dictionary
dict1[4]="Chennai"
print(dict1)
# removing values in a dictionary
del dict1[4]
print(dict1)
# Out:
# {1: 'Agra', 2: 'Amritsar', 3: 'Delhi'}
# {1: 'Agra', 2: 'Amritsar', 3: 'Delhi', 4: 'Mumbai'}
# {1: 'Agra', 2: 'Amritsar', 3: 'Delhi', 4: 'Chennai'}
# {1: 'Agra', 2: 'Amritsar', 3: 'Delhi'}

# %% [markdown]
# 5. Why might you use a set instead of a list in Python?
#    - we might use a set instead of a list in python in the cases where we need only unique unordered values. whereas in a list we can store ordered but duplicate values. so the use case of a set is when a user requires unique elements only if might there is a possibility of duplicates in a set definition, those duplicates will automatically be removed.

# %% [markdown]
# 6. What is a string in Python, and how is it different from a list?
#    - strings: a string is a sequence of characters which stores its values in either single qoutes or double qoutes. eg- str1="Python" str2="Programming". it is an immutable data type whose value cannot be changed after created once.
#    - Lists: a list is a container which can store n number of values. these can store heterogeneous data.these are defines using square brackets: list1=[1,2,3,4]
#    - Key differences:
#       - a list can store multiple values while a string can store a set of strings only, not more than one string.
#       - a list is a mutable data type while a string is a immutable data type.
#       - a list can store heterogeneous data in it, while string can only characters.
#       - a list iterate over its elements, while a string iterates over characters.
#       Many built-in string methods can be used(.upper(), .lower(), .replace(), etc.)	Many list methods can also be used (.append(), .extend(), .pop(), etc.)

# %% [markdown]
# 7. How do tuples ensure data integrity in Python?
#    - Tuples in Python are immutable ordered collections of elements, meaning their contents cannot be altered after creation. This immutability is a key feature that ensures data integrity by preventing unintended modifications to the data. Once a tuple is created, its elements cannot be changed, added, or removed. This immutability guarantees that the data remains consistent throughout the program's execution. For example, if a tuple is passed to a function, the function cannot modify its contents, ensuring the original data remains intact. Its immutability is the reason of it to maintain data integrity in python as python doesnot allow you to change data elements stored in tuples.

# %%
# Example of tuples ensuring data integrity
student_details = ("Kulpreet Kaur", "BCA-SEM-5","255203")
print(student_details)
student_details[2]="255204"
# Tuples allows data integrity as we cannot change data in a tuple once it is created.
# Out:
# ('Kulpreet Kaur', 'BCA-SEM-5', '255203')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3095124440.py in <cell line: 0>()
#       2 student_details = ("Kulpreet Kaur", "BCA-SEM-5","255203")
#       3 print(student_details)
# ----> 4 student_details[2]="255204"
#       5 # Tuples allows data integrity as we cannot change data in a tuple once it is created.
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
#  8. What is a hash table, and how does it relate to dictionaries in Python?
#     - A dictionary is a data structure that maps keys to values. its syntax includes eg: dict1={key:value}. in it keys are immutable but values can be mutable. A dictionary can include n number of key:value pairs.
#     - A hash table is a data structure that maps keys to values by taking the hash value of the key (by applying some hash function to it) and mapping that to a bucket where one or more values are stored.
#     - these both are related as a dictionary behaves like a hash table where similar to a hash table keys are mapped to values.

# %% [markdown]
# 9. Can lists contain different data types in Python?
#    - Yes, lists can store heterogeneous, ordered and mutable data in python. example can be seen below:

# %%
list1=["book1",1,1.1,True]
# As seen here, this list stores different data types including
# int,float,string,boolean
print(type(list1))
# Out:
# <class 'list'>

# %% [markdown]
# 10. Explain why strings are immutable in Python?
#     - Strings in python are sequence of characters, whose characters per index cannot be changed that makes strings immutable. example is given below:

# %%
str1="python programming"
str1[0]="P"
# Strings being immuatv=ble throws an error when single
# index is accessed and is tried to change a single character of a string
# hence, string object doesnot support item assignment.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-168371503.py in <cell line: 0>()
#       1 str1="python programming"
# ----> 2 str1[0]="P"
#       3 # Strings being immuatv=ble throws an error when single
#       4 # index is accessed and is tried to change a single character of a string
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# 11.  What advantages do dictionaries offer over lists for certain tasks?
# A key advantage of using dictionaries over lists in Python is their efficiency in searching and accessing elements. Dictionaries are implemented as hash tables, allowing for constant time complexity when retrieving a value using its key. In contrast, lists require a linear search, which becomes slower as the list grows larger. that is, lists take too much time for accessing items while dictionaries take less time to access elements due to its versatile structure, of key:value pairs.

# %% [markdown]
# 12. Describe a scenario where using a tuple would be preferable over a list?
#     - A tuple is more preferrable in the cases where we want our data to be immutable, i.e., we dont want to change our data after creating it once. for example, in a dataset, for storing Aadhar card, we can create a tuple data structure for storing these elmeents elements. as the values of aadhar cards of a person should not be changes, So, we can use tuple for storing those elements. In any scenario where we want our data to remain the same, and should avoid modification, we may use tuples.

# %% [markdown]
# 13. How do sets handle duplicate values in Python?
#     - Sets are a data structure storing unique, unordered elements in it. So, in any case where we want only unique elements from a list of elements, we can use sets, which will return unique elements, terminating the duplicate values.

# %%
# For example: use of sets
# in lists:
list1=[1,2,3,3,2,1]
set2=set(list1)
print(set2)
# it will return all the unique values and terminate the duplicates
# in strings:
str1="sms-Smart messageing system"
set1=set(str1)
print(set1)
# it will return all the unique values and terminate the duplicates
# Out:
# {1, 2, 3}
# {'S', 'a', 'g', 'y', 'm', 'i', 'r', 's', ' ', 'n', 't', '-', 'e'}

# %% [markdown]
# 14. How does the “in” keyword work differently for lists and dictionaries?
#     - The in keyword in Python is used to check for membership, but its behavior and efficiency differ depending on the data structure it is applied to, such as lists and dictionaries.
#     - in with Lists:
#      When used with a list, the in keyword checks if a value exists within the list. This operation involves iterating through the list sequentially and comparing each element with the target value.
#      - in with Dictionaries:
#      When used with a dictionary, the in keyword checks for the presence of a key, not a value. If you want to check for a value, you need to use the .values() method explicitly.

# %%
# Example of "in" in lists
list1=[1,2,3,4]
print(1 in list1)
print(6 in list1)
# here elements is checked using "in" operator
# Example of "in" in dictionary
dict1={1:"A",2:"B",3:"C"}
print(1 in dict1)
print(4 in dict1)
print("A" in dict1)
# here key's are checked in the dictionary using "in" operator
print("A" in dict1.values())
# here values are checked
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# 15. Can you modify the elements of a tuple? Explain why or why not?
#     - In Python, tuples are immutable, meaning once created, their elements cannot be changed, added, or removed directly. This immutability applies to the tuple object itself, not to the objects it contains. So, you cannot do.

# %%
# trying to add elements to an existing tuple
tuple1=(1,2,3,4)
tuple1.append(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3712887541.py in <cell line: 0>()
#       1 # trying to add elements to an existing tuple
#       2 tuple1=(1,2,3,4)
# ----> 3 tuple1.append(5)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# 16. What is a nested dictionary, and give an example of its use case?
#     - a nested dictionary is where there is another dictionary inside a dictionary.This allows you to store complex data structures in a single dictionary. Each key in the outer dictionary can map to another dictionary, enabling hierarchical data storage.

# %%
# example of nested dictionary:
dict_nested= {
    1 :{ "name": "Kulpreet", "age": 20, "city": "Jalandhar"},
    2 :{ "name": "Renu", "age": 25, "city": "Ludhiane"}
}
# accessing elements of a nested dictionary
print(dict_nested[1]["name"])
print(dict_nested[2]["city"])
# Out:
# Kulpreet
# Ludhiane

# %% [markdown]
# 17. Describe the time complexity of accessing elements in a dictionary.
#     - Accessing a value in a Python dictionary by its key has an average time complexity of O(1). This efficiency is due to the underlying implementation of dictionaries using hash tables. Hash tables allow for constant-time lookups by computing a hash of the key, which directly maps to a memory location where the value is stored. When you access a value using a key (e.g., dict[key]), the dictionary computes the hash of the key and uses it to locate the corresponding value in the hash table. This process avoids the need for linear or binary searches, making it extremely fast.

# %% [markdown]
# 18. In what situations are lists preferred over dictionaries?
#        Lists are preferred over dictionaries in situations where order matters, duplicates are allowed, and when you need to perform operations like appending or iterating through a sequence of items. lists can be used for:
#         - maintaining order
#         - allowing duplicates
#         - iterating over items

# %% [markdown]
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#     - Dictionaries in Python are often referred to as unordered collections because they do not guarantee any specific order of their elements based on insertion or key values. This characteristic stems from their underlying implementation as hash tables, which prioritize fast key-based lookups over maintaining order.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrieval
#     - In Python, lists and dictionaries are two fundamental data structures that serve different purposes and have distinct characteristics.
#     - Lists: A list is a collection of ordered elements that can be of multiple types. Lists are defined using square brackets [] or the list() function. For example: myList = [1, 2, 3, 4, 5, 6].
#     - Access and mutability Lists allow random access to elements using indices, which start from 0. Lists are mutable, meaning you can modify their elements after creation. You can add elements using methods like append() and extend(), and remove elements using methods like remove() and pop().
#     - Performance: Lists provide faster performance for initialization, accessing elements, and iterating. However, searching for an element in a list has an average time complexity of O(n). For example:

# %%
myList = [1, 2, 3, 4, 5, 6]
myList.append(10) # Adds 10 to the list
myList.extend([11, 12, 13]) # Adds multiple elements to the list
print(myList)
# Out:
# [1, 2, 3, 4, 5, 6, 10, 11, 12, 13]

# %% [markdown]
# - Dictionary: A dictionary is a collection of key-value pairs. Dictionaries are defined using curly braces {} or the dict() function. For example:myDict = {'Name': 'Geeks', 1: [1, 2, 3, 4]}.
# - Access and mutability: Dictionaries allow random access to values using keys, which must be of an immutable data type (e.g., integers, strings, tuples). Dictionaries are also mutable, allowing you to add, modify, or remove key-value pairs. You can add elements using the assignment operator or the update() method.
# - Performance: Dictionaries provide faster performance for lookups, insertions, and deletions due to their underlying hash table implementation. The average time complexity for these operations is O(1)
# For example:

# %%
myDict = {'Name': 'Geeks', 1: [1, 2, 3, 4]}
myDict['Age'] = 25 # Adds a new key-value pair
myDict.update({'Gender': 'Male'}) # Adds another key-value pair
print(myDict)
# Out:
# {'Name': 'Geeks', 1: [1, 2, 3, 4], 'Age': 25, 'Gender': 'Male'}

# %% [markdown]
# - When to Use
# - Lists:
# Use lists when the order of elements is important, when you need to access elements using numerical indices, or when duplicate values are allowed. Lists are ideal for scenarios where you need to maintain a sequence of elements and perform operations like sorting or slicing.
# - Dictionaries:
# Use dictionaries when you need to store data in key-value pairs, perform fast lookups, or ensure that keys are unique. Dictionaries are suitable for scenarios where you need to map unique keys to values, such as storing user information or configuration settings.

# %% [markdown]
# # Practical Questions

# %%
# 1. Write a code to create a string with your name and print it.
str1="Kulpreet Kaur Sembhi"
print(str1)
# Out:
# Kulpreet Kaur Sembhi

# %%
# 2. Write a code to find the length of the string "Hello World".
str1="Hello World"
print(len(str1))
# Out:
# 11

# %%
# 3. Write a code to slice the first 3 characters from
# the string "Python Programming".
str1="Python Programming"
print(str1[0:3])
# Out:
# Pyt

# %%
# 4. Write a code to convert the string "hello" to uppercase.
str1="hello"
print(str1.upper())
# Out:
# HELLO

# %%
# 5.  Write a code to replace the word "apple" with "orange"
# in the string "I like apple"
str1="I like apple"
print(str1.replace("apple","orange"))
# Out:
# I like orange

# %%
# 6. Write a code to create a list with numbers 1 to 5 and print it.
list1=[i for i in range(1,6)]
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].
list1=[1,2,3,4]
list1.append(10)
print(list1)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8.  Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
list1=[1,2,3,4,5]
list1.remove(3)
print(list1)
# Out:
# [1, 2, 4, 5]

# %%
# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
list1=['a','b','c','d']
print(list1[2]) #third index/third element
print(list1[1]) #second index/second element
# Out:
# c
# b

# %%
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].
list1=[10,20,30,40,50]
list1.reverse()
print(list1)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11.Write a code to create a tuple with the elements 100, 200, 300 and print it.
tuple1=(100,200,300)
print(tuple1)
# Out:
# (100, 200, 300)

# %%
# 12.Write a code to access the second-to-last element of the tuple
# ('red', 'green', 'blue', 'yellow')
tuple1=('red', 'green', 'blue', 'yellow')
print(tuple1[1:])
# Out:
# ('green', 'blue', 'yellow')

# %%
# 13.  Write a code to find the minimum number in the tuple (10, 20, 5, 15).
tup=(10,20,5,15)
print(min(tup))
# Out:
# 5

# %%
# 14. Write a code to find the index of the element "cat"
# in the tuple ('dog', 'cat', 'rabbit').
tuple1=('dog', 'cat', 'rabbit')
print(tuple1.index("cat"))
# Out:
# 1

# %%
# 15.Write a code to create a tuple containing three different
# fruits and check if "kiwi" is in it.
tuple1=("apple","banana","mango")
print("kiwi" in tuple1)
tuple2=("apple","orange","mango","kiwi")
print("kiwi" in tuple2)
# Out:
# False
# True

# %%
# 16.Write a code to create a set with the elements 'a', 'b', 'c' and print it.
set1={'a','b','c'}
print(set1)
# Out:
# {'c', 'a', 'b'}

# %%
# 17.Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
set1={1,2,3,4,5}
set1.clear()
print(set1)
# Out:
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}
set1={1,2,3,4}
set1.remove(4)
print(set1)
# Out:
# {1, 2, 3}

# %%
# 19.Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
set1={1,2,3}
set2={3,4,5}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
set1={1,2,3}
set2={2,3,4}
print(set1.intersection(set2))
# Out:
# {2, 3}

# %%
# 21. Write a code to create a dictionary with the keys
# "name", "age", and "city", and print it
dict1={"name":"Kulpreet","age":20,"city":"Jalandhar"}
print(dict1)
# Out:
# {'name': 'Kulpreet', 'age': 20, 'city': 'Jalandhar'}

# %%
# 22. Write a code to add a new key-value pair "country": "USA"
#  to the dictionary {'name': 'John', 'age': 25}
dict1= {'name': 'John', 'age': 25}
dict1["country"]="USA"
print(dict1)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
# 23.Write a code to access the value associated with the key "name"
# in the dictionary {'name': 'Alice', 'age': 30}.
dict1= {'name': 'Alice', 'age': 30}
print(dict1["name"])
# Out:
# Alice

# %%
# 24.Write a code to remove the key "age" from the
#  dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
dict1= {'name': 'Bob', 'age': 22, 'city': 'New York'}
dict1.pop('age')
print(dict1)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
# 25. Write a code to check if the key "city" exists in the
# dictionary {'name': 'Alice', 'city': 'Paris'}.
dict1= {'name': 'Alice', 'city': 'Paris'}
print("city" in dict1)
# Out:
# True

# %%
#26.Write a code to create a list, a tuple, and a dictionary, and print them all.
list1=[1,2,3,4,"list-no-1"]
tuple1=(1,2,3,4,"tuple-no-1")
dict1={"name":"Kulpreet","age":20,"city":"Jalandhar"}
print(list1)
print(tuple1)
print(dict1)
# Out:
# [1, 2, 3, 4, 'list-no-1']
# (1, 2, 3, 4, 'tuple-no-1')
# {'name': 'Kulpreet', 'age': 20, 'city': 'Jalandhar'}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100,
# sort it in ascending order, and print the  result.(replaced)
import random
list1=[random.randint(1,100) for i in range(5)]
print("Random list",list1)
sorted_list1=sorted(list1)
print("Sorted list",sorted_list1)
# Out:
# Random list [21, 24, 93, 17, 64]
# Sorted list [17, 21, 24, 64, 93]

# %%
# 28. Write a code to create a list with strings and print
# the element at the third index.
list1=["apple","banana","mango","orange","grapes"]
print(list1[3])
# Out:
# orange

# %%
# 29.  Write a code to combine two dictionaries into one and print the result.
dict1={"name":"Kulpreet","age":20}
dict2={"city":"Jalandhar","state":"Punjab","country":"India"}
dict1.update(dict2)
print(dict1)
# Out:
# {'name': 'Kulpreet', 'age': 20, 'city': 'Jalandhar', 'state': 'Punjab', 'country': 'India'}

# %%
# 30. Write a code to convert a list of strings into a set.
list1=["apple","banana","mango","orange","grapes"]
print("List=",list1)
print(type(list1))
set1=set(list1)
print("Set=",set1)
print(type(set1))
# Out:
# List= ['apple', 'banana', 'mango', 'orange', 'grapes']
# <class 'list'>
# Set= {'orange', 'mango', 'grapes', 'banana', 'apple'}
# <class 'set'>
